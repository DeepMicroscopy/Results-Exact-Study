# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
from fastai.callbacks import *

# %%
folder = Path('D:/ProgProjekte/Python/Results-Exact-Study/Patches')

# %%
path = folder/"ExpertAlgorithm/All"

# %%
tfms = get_transforms(do_flip=True, 
                      flip_vert=True, 
                      max_rotate=90,  
                      #max_lighting=0.0, 
                      #max_zoom=2, 
                      #max_warp=0.2,
                      #p_affine=0.75,
                      #p_lighting=0.75,  
                      #xtra_tfms=xtra_tfms,
                     )

# %%
def get_data(bs,size):
    data = ImageDataBunch.from_folder(path, train="train", valid="val", size=size, bs=bs, ds_tfms=tfms, num_workers=0)
    return data.normalize()

# %%
data = get_data(64,64)
fig = data.show_batch(3, return_fig=True)

# %%
learn = cnn_learner(get_data(bs=64, size=64), models.resnet18, metrics=[error_rate, accuracy], callback_fns=[ShowGraph])
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [2/4 00:18<00:18]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.946319</td>
#       <td>#na#</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.836340</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24' class='' max='32', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [24/32 00:05<00:01 1.9326]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 0.05
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.758451</td>
#       <td>0.878358</td>
#       <td>0.319460</td>
#       <td>0.680540</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.664291</td>
#       <td>0.684738</td>
#       <td>0.211474</td>
#       <td>0.788526</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.563083</td>
#       <td>0.341550</td>
#       <td>0.147919</td>
#       <td>0.852081</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.446065</td>
#       <td>0.322316</td>
#       <td>0.122047</td>
#       <td>0.877953</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.352080</td>
#       <td>0.311336</td>
#       <td>0.127672</td>
#       <td>0.872328</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

# %%
lr = 0.001
learn.fit_one_cycle(10, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.265076</td>
#       <td>0.303069</td>
#       <td>0.124859</td>
#       <td>0.875141</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.261547</td>
#       <td>0.267797</td>
#       <td>0.114173</td>
#       <td>0.885827</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.258881</td>
#       <td>0.253721</td>
#       <td>0.110236</td>
#       <td>0.889764</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.254451</td>
#       <td>0.251358</td>
#       <td>0.111924</td>
#       <td>0.888076</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.236329</td>
#       <td>0.252133</td>
#       <td>0.110799</td>
#       <td>0.889201</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.225867</td>
#       <td>0.239874</td>
#       <td>0.107987</td>
#       <td>0.892013</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.224233</td>
#       <td>0.236921</td>
#       <td>0.105737</td>
#       <td>0.894263</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.215487</td>
#       <td>0.237172</td>
#       <td>0.103487</td>
#       <td>0.896513</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.203344</td>
#       <td>0.233181</td>
#       <td>0.104049</td>
#       <td>0.895950</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.202687</td>
#       <td>0.232011</td>
#       <td>0.102362</td>
#       <td>0.897638</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
